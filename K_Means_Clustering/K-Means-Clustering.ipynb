# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings as w
w.filterwarnings('ignore')

# %%
ds = pd.read_csv('Spot_2021_07.csv')
x = ds.iloc[:,[5,6]].values
print(x)
# Out:
# [[ 905825 1501675]
#  [ 905525 1500975]
#  [ 907175 1501675]
#  ...
#  [ 946725 1493425]
#  [ 947325 1496725]
#  [ 947475 1497575]]

# %%
from sklearn.cluster import KMeans
wcss = []

# %%
kmeans = KMeans(n_clusters=50,init='k-means++',random_state=0)
y_kmeans = kmeans.fit_predict(x)

# %%
# plt.scatter(x[y_kmeans==0,0],x[y_kmeans==0,1],s=100, c='red',label='Cluster 1')
# plt.scatter(x[y_kmeans==1,0],x[y_kmeans==1,1],s=100, c='blue',label='Cluster 2')
# plt.scatter(x[y_kmeans==2,0],x[y_kmeans==2,1],s=100, c='green',label='Cluster 3')
# plt.scatter(x[y_kmeans==3,0],x[y_kmeans==3,1],s=100, c='black',label='Cluster 4')
# plt.scatter(x[y_kmeans==4,0],x[y_kmeans==4,1],s=100, c='pink',label='Cluster 5')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1], s=300, c='yellow', label = 'Centroids')
plt.title('Clusters of Spot')
plt.xlabel('Xrecords)')
plt.ylabel('Yrecords')
plt.legend()
plt.show()

# %%
centroids_x = kmeans.cluster_centers_[:, 0]
centroids_y = kmeans.cluster_centers_[:, 1]
for i in range(len(centroids_x)):
    print(f"Centroid {i+1}: ({centroids_x[i]}, {centroids_y[i]})")
# Out:
# Centroid 1: (909217.4242424242, 1502815.9090909092)
# Centroid 2: (899572.8260869565, 1472988.043478261)
# Centroid 3: (936425.0, 1499650.0)
# Centroid 4: (883041.6666666666, 1489722.9166666667)
# Centroid 5: (907452.7777777778, 1473091.6666666667)
# Centroid 6: (889895.8333333334, 1479987.5)
# Centroid 7: (889384.6153846154, 1496930.7692307692)
# Centroid 8: (946048.0769230769, 1494280.7692307692)
# Centroid 9: (938106.25, 1481406.25)
# Centroid 10: (922807.3529411765, 1505904.4117647058)
# Centroid 11: (918225.0, 1473900.0)
# Centroid 12: (889020.8333333334, 1472337.5)
# Centroid 13: (905250.0, 1501425.0)
# Centroid 14: (920235.0, 1494345.0)
# Centroid 15: (893646.4285714285, 1489500.0)
# Centroid 16: (930208.3333333334, 1492250.0)
# Centroid 17: (931732.1428571428, 1506289.2857142857)
# Centroid 18: (914175.0, 1473050.0)
# Centroid 19: (896984.0909090909, 1499815.9090909092)
# Centroid 20: (906625.0, 1500186.5384615385)
# Centroid 21: (946796.7391304348, 1497698.9130434783)
# Centroid 22: (876650.0, 1484275.0)
# Centroid 23: (883025.0, 1471615.0)
# Centroid 24: (916050.0, 1478750.0)
# Centroid 25: (939435.0, 1504665.0)
# Centroid 26: (907154.6875, 1502526.5625)
# Centroid 27: (890265.0, 1484885.0)
# Centroid 28: (894987.5, 1474125.0)
# Centroid 29: (902996.875, 1500850.0)
# Centroid 30: (923041.6666666666, 1476191.6666666667)
# Centroid 31: (893975.0, 1478095.0)
# Centroid 32: (880458.3333333334, 1487591.6666666667)
# Centroid 33: (899650.0, 1493950.0)
# Centroid 34: (925875.0, 1498925.0)
# Centroid 35: (932262.5, 1495668.75)
# Centroid 36: (886158.3333333334, 1476841.6666666667)
# Centroid 37: (904965.0, 1498010.0)
# Centroid 38: (893175.0, 1498425.0)
# Centroid 39: (913175.0, 1502975.0)
# Centroid 40: (887208.3333333334, 1468991.6666666667)
# Centroid 41: (927775.0, 1507400.0)
# Centroid 42: (884975.0, 1491791.6666666667)
# Centroid 43: (913325.0, 1495750.0)
# Centroid 44: (887413.8888888889, 1479669.4444444445)
# Centroid 45: (934550.0, 1507375.0)
# Centroid 46: (924225.0, 1489525.0)
# Centroid 47: (912393.75, 1473175.0)
# Centroid 48: (919475.0, 1499000.0)
# Centroid 49: (934075.0, 1487975.0)
# Centroid 50: (898619.8275862068, 1474218.103448276)

# %%
centroids = pd.DataFrame(kmeans.cluster_centers_, columns=['x', 'y'])

# %%
centroids.to_csv('2021_07_50.csv', index=False)
